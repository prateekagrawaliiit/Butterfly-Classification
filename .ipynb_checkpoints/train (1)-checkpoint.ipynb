# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import StratifiedKFold
import tqdm
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense,Dropout,BatchNormalization,GlobalAveragePooling2D
from tensorflow.keras.models import Sequential,load_model
from tensorflow.keras.optimizers import Adam
import tensorflow_addons as tfa 
from tensorflow.keras.callbacks import ReduceLROnPlateau,ModelCheckpoint,EarlyStopping
import matplotlib.pyplot as plt
import tensorflow.keras.backend as K
import keras 
from keras.utils import to_categorical
from sklearn.metrics import confusion_matrix
import efficientnet.tfkeras as efn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-603674d4cd81> in <module>
#       3 from sklearn.model_selection import StratifiedKFold
#       4 import tqdm
# ----> 5 import tensorflow as tf
#       6 from tensorflow.keras.preprocessing.image import ImageDataGenerator
#       7 from tensorflow.keras.applications import ResNet50
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
SEED=42
TRAIN_DIR='data/TRAIN'
TEST_DIR='data/TEST/'
IMG_SIZE=(224,224)
BATCHSIZE=48
INPUT_SHAPE=(224,224,3)
EPOCHS=70
LR=1e-4

# %%
train_datagen=ImageDataGenerator(rescale=1/128,validation_split=0.1)
valid_datagen=ImageDataGenerator(rescale=1/255,validation_split=0.9)

# %%
train_batches=train_datagen.flow_from_directory(TRAIN_DIR,target_size=IMG_SIZE,batch_size=BATCHSIZE,shuffle=True,seed=SEED,subset='training')
# Out:
# Found 4050 images belonging to 50 classes.

# %%
valid_batches=train_datagen.flow_from_directory(TRAIN_DIR,target_size=IMG_SIZE,batch_size=BATCHSIZE,shuffle=False,seed=SEED,subset='validation')
# Out:
# Found 429 images belonging to 50 classes.

# %%
res=ResNet50(weights='imagenet',include_top=False,input_shape=INPUT_SHAPE)
eff=efn.EfficientNetB0(weights='imagenet',include_top=False,input_shape=INPUT_SHAPE)

# %%
def f1_metric(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
model=Sequential()
model.add(eff)
model.add(Dropout(0.3))
model.add(GlobalAveragePooling2D())
model.add(Dense(50,activation='softmax'))

# %%
model.compile(optimizer=Adam(lr=LR),loss='categorical_crossentropy',metrics=[f1_metric])

# %%
redlr=ReduceLROnPlateau(monitor='val_loss',patience=3,verbose=1)
chkpt=ModelCheckpoint('best.h5',verbose=1,monitor='val_loss',save_best_only=True)
es=EarlyStopping(patience=8,verbose=1,restore_best_weights=True)

# %%
history=model.fit(train_batches,validation_data=valid_batches,epochs=EPOCHS,callbacks=[redlr,chkpt,es],verbose=1)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 85 steps, validate for 9 steps
# Epoch 1/70
# 84/85 [============================>.] - ETA: 0s - loss: 3.1628 - f1_metric: 0.0233
# Epoch 00001: val_loss improved from inf to 1.72993, saving model to best.h5
# 85/85 [==============================] - 46s 541ms/step - loss: 3.1519 - f1_metric: 0.0244 - val_loss: 1.7299 - val_f1_metric: 0.3220
# Epoch 2/70
# 84/85 [============================>.] - ETA: 0s - loss: 1.2230 - f1_metric: 0.5283
# Epoch 00002: val_loss improved from 1.72993 to 0.51266, saving model to best.h5
# 85/85 [==============================] - 32s 379ms/step - loss: 1.2168 - f1_metric: 0.5313 - val_loss: 0.5127 - val_f1_metric: 0.8463
# Epoch 3/70
# 84/85 [============================>.] - ETA: 0s - loss: 0.4720 - f1_metric: 0.8775
# Epoch 00003: val_loss improved from 0.51266 to 0.31082, saving model to best.h5
# 85/85 [==============================] - 32s 378ms/step - loss: 0.4714 - f1_metric: 0.8775 - val_loss: 0.3108 - val_f1_metric: 0.9096
# Epoch 4/70
# 84/85 [============================>.] - ETA: 0s - loss: 0.2501 - f1_metric: 0.9472
# Epoch 00004: val_loss improved from 0.31082 to 0.23737, saving model to best.h5
# 85/85 [==============================] - 32s 377ms/step - loss: 0.2496 - f1_metric: 0.9473 - val_loss: 0.2374 - val_f1_metric: 0.9451
# Epoch 5/70
# 84/85 [============================>.] - ETA: 0s - loss: 0.1514 - f1_metric: 0.9734
# Epoch 00005: val_loss improved from 0.23737 to 0.20886, saving model to best.h5
# 85/85 [==============================] - 32s 378ms/step - loss: 0.1513 - f1_metric: 0.9733 - val_loss: 0.2089 - val_f1_metric: 0.9441
# Epoch 6/70
# 84/85 [============================>.] - ETA: 0s - loss: 0.0950 - f1_metric: 0.9852
# Epoch 00006: val_loss improved from 0.20886 to 0.18897, saving model to best.h5
# 85/85 [==============================] - 32s 374ms/step - loss: 0.0958 - f1_metric: 0.9847 - val_loss: 0.1890 - val_f1_metric: 0.9524
# Epoch 7/70
# 84/85 [============================>.] - ETA: 0s - loss: 0.0645 - f1_metric: 0.9922
# Epoch 00007: val_loss improved from 0.18897 to 0.18118, saving model to best.h5
# 85/85 [==============================] - 32s 376ms/step - loss: 0.0644 - f1_metric: 0.9921 - val_loss: 0.1812 - val_f1_metric: 0.9562
# Epoch 8/70
# 84/85 [============================>.] - ETA: 0s - loss: 0.0446 - f1_metric: 0.9957
# Epoch 00008: val_loss did not improve from 0.18118
# 85/85 [==============================] - 30s 355ms/step - loss: 0.0449 - f1_metric: 0.9957 - val_loss: 0.1823 - val_f1_metric: 0.9550
# Epoch 9/70
# 84/85 [============================>.] - ETA: 0s - loss: 0.0319 - f1_metric: 0.9975
# Epoch 00009: val_loss did not improve from 0.18118
# 85/85 [==============================] - 30s 356ms/step - loss: 0.0321 - f1_metric: 0.9974 - val_loss: 0.1844 - val_f1_metric: 0.9551
# Epoch 10/70
# 84/85 [============================>.] - ETA: 0s - loss: 0.0270 - f1_metric: 0.9973
# Epoch 00010: val_loss improved from 0.18118 to 0.17287, saving model to best.h5
# 85/85 [==============================] - 32s 380ms/step - loss: 0.0268 - f1_metric: 0.9973 - val_loss: 0.1729 - val_f1_metric: 0.9554
# Epoch 11/70
# 84/85 [============================>.] - ETA: 0s - loss: 0.0186 - f1_metric: 0.9994
# Epoch 00011: val_loss did not improve from 0.17287
# 85/85 [==============================] - 30s 357ms/step - loss: 0.0185 - f1_metric: 0.9994 - val_loss: 0.1831 - val_f1_metric: 0.9601
# Epoch 12/70
# 84/85 [============================>.] - ETA: 0s - loss: 0.0157 - f1_metric: 0.9990
# Epoch 00012: val_loss did not improve from 0.17287
# 85/85 [==============================] - 30s 356ms/step - loss: 0.0162 - f1_metric: 0.9989 - val_loss: 0.1797 - val_f1_metric: 0.9613
# Epoch 13/70
# 84/85 [============================>.] - ETA: 0s - loss: 0.0145 - f1_metric: 0.9987
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
#
# Epoch 00013: val_loss did not improve from 0.17287
# 85/85 [==============================] - 30s 358ms/step - loss: 0.0144 - f1_metric: 0.9988 - val_loss: 0.1853 - val_f1_metric: 0.9577
# Epoch 14/70
# 84/85 [============================>.] - ETA: 0s - loss: 0.0116 - f1_metric: 0.9991
# Epoch 00014: val_loss did not improve from 0.17287
# 85/85 [==============================] - 30s 358ms/step - loss: 0.0116 - f1_metric: 0.9991 - val_loss: 0.1845 - val_f1_metric: 0.9577
# Epoch 15/70
# 84/85 [============================>.] - ETA: 0s - loss: 0.0103 - f1_metric: 0.9996
# Epoch 00015: val_loss did not improve from 0.17287
# 85/85 [==============================] - 30s 358ms/step - loss: 0.0103 - f1_metric: 0.9996 - val_loss: 0.1842 - val_f1_metric: 0.9577
# Epoch 16/70
# 84/85 [============================>.] - ETA: 0s - loss: 0.0102 - f1_metric: 0.9991
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 00016: val_loss did not improve from 0.17287
# 85/85 [==============================] - 31s 360ms/step - loss: 0.0102 - f1_metric: 0.9991 - val_loss: 0.1836 - val_f1_metric: 0.9577
# Epoch 17/70
# 84/85 [============================>.] - ETA: 0s - loss: 0.0101 - f1_metric: 0.9996
# Epoch 00017: val_loss did not improve from 0.17287
# 85/85 [==============================] - 31s 360ms/step - loss: 0.0101 - f1_metric: 0.9996 - val_loss: 0.1839 - val_f1_metric: 0.9590
# Epoch 18/70
# 84/85 [============================>.] - ETA: 0s - loss: 0.0099 - f1_metric: 0.9996
# Epoch 00018: val_loss did not improve from 0.17287
# Restoring model weights from the end of the best epoch.
# 85/85 [==============================] - 30s 358ms/step - loss: 0.0099 - f1_metric: 0.9996 - val_loss: 0.1832 - val_f1_metric: 0.9590
# Epoch 00018: early stopping

# %%
print(history.history.keys())

plt.plot(history.history['f1_metric'])
plt.plot(history.history['val_f1_metric'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'f1_metric', 'val_loss', 'val_f1_metric', 'lr'])

# %%
test_batches=ImageDataGenerator(rescale=1/255).flow_from_directory("data/TEST",target_size=IMG_SIZE,shuffle=False,class_mode=None,seed=SEED,batch_size=BATCHSIZE)
# Out:
# Found 500 images belonging to 1 classes.

# %%
model=load_model('best.h5',custom_objects={'f1_metric':f1_metric})

# %%
test_preds=model.predict_generator(test_batches,verbose=1)
# Out:
# WARNING:tensorflow:From <ipython-input-15-bfcea90b9891>:1: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.
# 11/11 [==============================] - 5s 439ms/step

# %%
test_preds=test_preds.argmax(axis=-1)

# %%
idx_to_cls = {v: k for k, v in train_batches.class_indices.items()}
prediction_cls= np.vectorize(idx_to_cls.get)(test_preds)
filenames_to_cls = list(zip(test_batches.filenames, prediction_cls))

# %%
data = pd.DataFrame(filenames_to_cls)

# %%
data.columns = ['Filename', 'Labels']

# %%
data.head()
# Out:
#        Filename            Labels
# 0  TEST\000.jpg       red admiral
# 1  TEST\001.jpg    straited queen
# 2  TEST\002.jpg         metalmark
# 3  TEST\003.jpg  pipevine swallow
# 4  TEST\004.jpg    scarce swallow

# %%
data['Filename'] = pd.DataFrame(os.listdir("data/TEST/TEST"))

# %%
data.head()
# Out:
#   Filename            Labels
# 0  000.jpg       red admiral
# 1  001.jpg    straited queen
# 2  002.jpg         metalmark
# 3  003.jpg  pipevine swallow
# 4  004.jpg    scarce swallow

# %%
data.to_csv('submissions/eff-bo-224-cv-0.9554-rescale-128.csv', index = False)
